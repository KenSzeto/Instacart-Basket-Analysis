# %% [markdown]
# # 4.8 Grouping Data and Aggregating Variables

# %% [markdown]
# ## Contents
#
# 1. Importing Libraries
# 2. Importing Data
# 3. Aggregating Data
# 4. Exporting Data

# %% [markdown]
# ## 01. Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 02. Importing Data

# %%
path = r'C:\Users\kensz\Documents\orders_products_merged_with_new_variables'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, 'orders_products_merged_with_new_variables.pkl'))

# %%
ords_prods_merge.head(5)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2398795        1             2                   3                  7
# 1    473747        1             3                   3                 12
# 2   2254736        1             4                   4                  7
# 3    431534        1             5                   4                 15
# 4   3367565        1             6                   2                  7
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                    15.0         196                  1          1
# 1                    21.0         196                  1          1
# 2                    29.0         196                  1          1
# 3                    28.0         196                  1          1
# 4                    19.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# 0         Soda        77              7     9.0   both  Mid-range product
# 1         Soda        77              7     9.0   both  Mid-range product
# 2         Soda        77              7     9.0   both  Mid-range product
# 3         Soda        77              7     9.0   both  Mid-range product
# 4         Soda        77              7     9.0   both  Mid-range product
#
#       busiest_day     busiest_days   busiest_hours busiest_period_of_day
# 0  Regularly Busy  Least Busy Days  Average Orders        Average Orders
# 1  Regularly Busy  Least Busy Days     Most Orders           Most Orders
# 2      Least Busy  Least Busy Days  Average Orders        Average Orders
# 3      Least Busy  Least Busy Days     Most Orders           Most Orders
# 4  Regularly Busy   Regularly Busy  Average Orders        Average Orders

# %%
ords_prods_merge.shape
# Out:
# (30328763, 19)

# %% [markdown]
# ## 03. Aggregating Columns

# %%
#aggregated mean for order_number grouped by department id

ords_prods_merge.groupby('department_id').agg({'order_number':['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                16.559358
# 2                18.413176
# 3                18.279600
# 4                18.915890
# 5                16.497751
# 6                17.609390
# 7                18.303975
# 8                16.383301
# 9                17.022963
# 10               21.227447
# 11               17.311768
# 12               16.953613
# 13               17.727470
# 14               17.898097
# 15               17.290123
# 16               18.757796
# 17               16.808683
# 18               20.336389
# 19               18.258620
# 20               17.578959
# 21               23.644477

# %% [markdown]
# Compared to running the same process on the subset of data during the task, this data is significantly different. The first noticeable difference is that theis returns data for all of the departments, while the subset of the first 1,000,000 only included five departments. Additionally the means of columns included in the subset have changed, presumeably because new values are being included in the calculation for the department compared to the subset.

# %% [markdown]
# ### Spending Habits Based off Loyalty Status

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty flag'] = 'Loyal Customer'
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty flag'] = 'Regular Customer'
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 10, 'loyalty flag')] ='New Customer'

# %%
ords_prods_merge['loyalty flag'].value_counts(dropna = False)
# Out:
# Regular Customer    15081691
# Loyal Customer      10095381
# New Customer         5151691
# Name: loyalty flag, dtype: int64

# %%
ords_prods_merge.groupby('loyalty flag').agg({'prices':['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty flag
# Loyal Customer    10.402162  1.0  99999.0
# New Customer      13.396333  1.0  99999.0
# Regular Customer  12.546842  1.0  99999.0

# %% [markdown]
# There is no signifigant difference between the spending habits of customers based off thier loyalty.

# %% [markdown]
# ### Targeting Based on Spending Habits

# %%
ords_prods_merge.groupby('user_id').agg({'prices': ['mean']})
# Out:
#            prices
#              mean
# user_id
# 1        6.372222
# 2        7.583516
# 3        8.302564
# 4        7.607143
# 5        9.365385
# ...           ...
# 206205   9.066667
# 206206   7.601068
# 206207   7.186432
# 206208   8.380150
# 206209   7.051724
#
# [206208 rows x 1 columns]

# %%
ords_prods_merge['average_prices'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
ords_prods_merge.head(25)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2398795        1             2                   3                  7
# 1     473747        1             3                   3                 12
# 2    2254736        1             4                   4                  7
# 3     431534        1             5                   4                 15
# 4    3367565        1             6                   2                  7
# 5     550135        1             7                   1                  9
# 6    3108588        1             8                   1                 14
# 7    2295261        1             9                   1                 16
# 8    2550362        1            10                   4                  8
# 9    2968173       15            15                   1                  9
# 10   1870022       15            17                   2                 16
# 11   1911383       15            18                   2                 11
# 12   2715276       15            21                   1                  9
# 13    487368       15            22                   1                 10
# 14   2293453       19             2                   5                 14
# 15   1973799       19             5                   6                 12
# 16    532817       19             7                   4                 17
# 17   1573906       21            10                   3                 10
# 18   1593000       31            10                   3                  8
# 19   2231262       31            17                   3                 11
# 20   2580647       43             6                   4                 16
# 21   2187180       43             9                   4                 12
# 22   1318871       52             2                   1                 10
# 23   1261384       52             3                   1                 10
# 24    580568       52             5                   2                 10
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     15.0         196                  1          1
# 1                     21.0         196                  1          1
# 2                     29.0         196                  1          1
# 3                     28.0         196                  1          1
# 4                     19.0         196                  1          1
# 5                     20.0         196                  1          1
# 6                     14.0         196                  2          1
# 7                      0.0         196                  4          1
# 8                     30.0         196                  1          1
# 9                      7.0         196                  2          0
# 10                     8.0         196                  6          1
# 11                     7.0         196                  1          1
# 12                     7.0         196                  1          1
# 13                    14.0         196                  1          1
# 14                     6.0         196                  3          0
# 15                     8.0         196                 15          1
# 16                     6.0         196                  1          1
# 17                     6.0         196                  2          0
# 18                     7.0         196                 17          0
# 19                     8.0         196                 14          1
# 20                     4.0         196                  9          0
# 21                     3.0         196                  1          1
# 22                     7.0         196                  5          1
# 23                     7.0         196                  3          1
# 24                     8.0         196                  6          1
#
#    product_name  ...  prices  _merge    price_range_loc     busiest_day  \
# 0          Soda  ...     9.0    both  Mid-range product  Regularly Busy
# 1          Soda  ...     9.0    both  Mid-range product  Regularly Busy
# 2          Soda  ...     9.0    both  Mid-range product      Least Busy
# 3          Soda  ...     9.0    both  Mid-range product      Least Busy
# 4          Soda  ...     9.0    both  Mid-range product  Regularly Busy
# 5          Soda  ...     9.0    both  Mid-range product  Regularly Busy
# 6          Soda  ...     9.0    both  Mid-range product  Regularly Busy
# 7          Soda  ...     9.0    both  Mid-range product  Regularly Busy
# 8          Soda  ...     9.0    both  Mid-range product      Least Busy
# 9          Soda  ...     9.0    both  Mid-range product  Regularly Busy
# 10         Soda  ...     9.0    both  Mid-range product  Regularly Busy
# 11         Soda  ...     9.0    both  Mid-range product  Regularly Busy
# 12         Soda  ...     9.0    both  Mid-range product  Regularly Busy
# 13         Soda  ...     9.0    both  Mid-range product  Regularly Busy
# 14         Soda  ...     9.0    both  Mid-range product  Regularly Busy
# 15         Soda  ...     9.0    both  Mid-range product  Regularly Busy
# 16         Soda  ...     9.0    both  Mid-range product      Least Busy
# 17         Soda  ...     9.0    both  Mid-range product  Regularly Busy
# 18         Soda  ...     9.0    both  Mid-range product  Regularly Busy
# 19         Soda  ...     9.0    both  Mid-range product  Regularly Busy
# 20         Soda  ...     9.0    both  Mid-range product      Least Busy
# 21         Soda  ...     9.0    both  Mid-range product      Least Busy
# 22         Soda  ...     9.0    both  Mid-range product  Regularly Busy
# 23         Soda  ...     9.0    both  Mid-range product  Regularly Busy
# 24         Soda  ...     9.0    both  Mid-range product  Regularly Busy
#
#        busiest_days   busiest_hours busiest_period_of_day max_order  \
# 0   Least Busy Days  Average Orders        Average Orders        10
# 1   Least Busy Days     Most Orders           Most Orders        10
# 2   Least Busy Days  Average Orders        Average Orders        10
# 3   Least Busy Days     Most Orders           Most Orders        10
# 4    Regularly Busy  Average Orders        Average Orders        10
# 5      Busiest Days  Average Orders        Average Orders        10
# 6      Busiest Days     Most Orders           Most Orders        10
# 7      Busiest Days  Average Orders        Average Orders        10
# 8   Least Busy Days  Average Orders        Average Orders        10
# 9      Busiest Days  Average Orders        Average Orders        22
# 10   Regularly Busy  Average Orders        Average Orders        22
# 11   Regularly Busy     Most Orders           Most Orders        22
# 12     Busiest Days  Average Orders        Average Orders        22
# 13     Busiest Days     Most Orders           Most Orders        22
# 14   Regularly Busy     Most Orders           Most Orders         9
# 15   Regularly Busy     Most Orders           Most Orders         9
# 16  Least Busy Days  Average Orders        Average Orders         9
# 17  Least Busy Days     Most Orders           Most Orders        33
# 18  Least Busy Days  Average Orders        Average Orders        20
# 19  Least Busy Days     Most Orders           Most Orders        20
# 20  Least Busy Days  Average Orders        Average Orders        11
# 21  Least Busy Days     Most Orders           Most Orders        11
# 22     Busiest Days     Most Orders           Most Orders        27
# 23     Busiest Days     Most Orders           Most Orders        27
# 24   Regularly Busy     Most Orders           Most Orders        27
#
#         loyalty flag  average_prices
# 0       New Customer        6.372222
# 1       New Customer        6.372222
# 2       New Customer        6.372222
# 3       New Customer        6.372222
# 4       New Customer        6.372222
# 5       New Customer        6.372222
# 6       New Customer        6.372222
# 7       New Customer        6.372222
# 8       New Customer        6.372222
# 9   Regular Customer        3.994118
# 10  Regular Customer        3.994118
# 11  Regular Customer        3.994118
# 12  Regular Customer        3.994118
# 13  Regular Customer        3.994118
# 14      New Customer        8.464535
# 15      New Customer        8.464535
# 16      New Customer        8.464535
# 17  Regular Customer        6.987500
# 18  Regular Customer        8.203147
# 19  Regular Customer        8.203147
# 20  Regular Customer        7.323944
# 21  Regular Customer        7.323944
# 22  Regular Customer        6.330435
# 23  Regular Customer        6.330435
# 24  Regular Customer        6.330435
#
# [25 rows x 22 columns]

# %%
ords_prods_merge.loc[ords_prods_merge['average_prices'] < 10, 'Spending_Flag'] = 'Low Spender'
ords_prods_merge.loc[ords_prods_merge['average_prices'] >= 10, 'Spending_Flag'] = 'High Spender'ords

# %%
ords_prods_merge['Spending_Flag'].value_counts(dropna = False)
# Out:
# Low Spender     29730505
# High Spender      598258
# Name: Spending_Flag, dtype: int64

# %% [markdown]
# ### Order Frequnecy

# %%
ords_prods_merge['median_order_frequency'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
ords_prods_merge.head(25)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2398795        1             2                   3                  7
# 1     473747        1             3                   3                 12
# 2    2254736        1             4                   4                  7
# 3     431534        1             5                   4                 15
# 4    3367565        1             6                   2                  7
# 5     550135        1             7                   1                  9
# 6    3108588        1             8                   1                 14
# 7    2295261        1             9                   1                 16
# 8    2550362        1            10                   4                  8
# 9    2968173       15            15                   1                  9
# 10   1870022       15            17                   2                 16
# 11   1911383       15            18                   2                 11
# 12   2715276       15            21                   1                  9
# 13    487368       15            22                   1                 10
# 14   2293453       19             2                   5                 14
# 15   1973799       19             5                   6                 12
# 16    532817       19             7                   4                 17
# 17   1573906       21            10                   3                 10
# 18   1593000       31            10                   3                  8
# 19   2231262       31            17                   3                 11
# 20   2580647       43             6                   4                 16
# 21   2187180       43             9                   4                 12
# 22   1318871       52             2                   1                 10
# 23   1261384       52             3                   1                 10
# 24    580568       52             5                   2                 10
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     15.0         196                  1          1
# 1                     21.0         196                  1          1
# 2                     29.0         196                  1          1
# 3                     28.0         196                  1          1
# 4                     19.0         196                  1          1
# 5                     20.0         196                  1          1
# 6                     14.0         196                  2          1
# 7                      0.0         196                  4          1
# 8                     30.0         196                  1          1
# 9                      7.0         196                  2          0
# 10                     8.0         196                  6          1
# 11                     7.0         196                  1          1
# 12                     7.0         196                  1          1
# 13                    14.0         196                  1          1
# 14                     6.0         196                  3          0
# 15                     8.0         196                 15          1
# 16                     6.0         196                  1          1
# 17                     6.0         196                  2          0
# 18                     7.0         196                 17          0
# 19                     8.0         196                 14          1
# 20                     4.0         196                  9          0
# 21                     3.0         196                  1          1
# 22                     7.0         196                  5          1
# 23                     7.0         196                  3          1
# 24                     8.0         196                  6          1
#
#    product_name  ...    price_range_loc     busiest_day     busiest_days  \
# 0          Soda  ...  Mid-range product  Regularly Busy  Least Busy Days
# 1          Soda  ...  Mid-range product  Regularly Busy  Least Busy Days
# 2          Soda  ...  Mid-range product      Least Busy  Least Busy Days
# 3          Soda  ...  Mid-range product      Least Busy  Least Busy Days
# 4          Soda  ...  Mid-range product  Regularly Busy   Regularly Busy
# 5          Soda  ...  Mid-range product  Regularly Busy     Busiest Days
# 6          Soda  ...  Mid-range product  Regularly Busy     Busiest Days
# 7          Soda  ...  Mid-range product  Regularly Busy     Busiest Days
# 8          Soda  ...  Mid-range product      Least Busy  Least Busy Days
# 9          Soda  ...  Mid-range product  Regularly Busy     Busiest Days
# 10         Soda  ...  Mid-range product  Regularly Busy   Regularly Busy
# 11         Soda  ...  Mid-range product  Regularly Busy   Regularly Busy
# 12         Soda  ...  Mid-range product  Regularly Busy     Busiest Days
# 13         Soda  ...  Mid-range product  Regularly Busy     Busiest Days
# 14         Soda  ...  Mid-range product  Regularly Busy   Regularly Busy
# 15         Soda  ...  Mid-range product  Regularly Busy   Regularly Busy
# 16         Soda  ...  Mid-range product      Least Busy  Least Busy Days
# 17         Soda  ...  Mid-range product  Regularly Busy  Least Busy Days
# 18         Soda  ...  Mid-range product  Regularly Busy  Least Busy Days
# 19         Soda  ...  Mid-range product  Regularly Busy  Least Busy Days
# 20         Soda  ...  Mid-range product      Least Busy  Least Busy Days
# 21         Soda  ...  Mid-range product      Least Busy  Least Busy Days
# 22         Soda  ...  Mid-range product  Regularly Busy     Busiest Days
# 23         Soda  ...  Mid-range product  Regularly Busy     Busiest Days
# 24         Soda  ...  Mid-range product  Regularly Busy   Regularly Busy
#
#      busiest_hours busiest_period_of_day max_order      loyalty flag  \
# 0   Average Orders        Average Orders        10      New Customer
# 1      Most Orders           Most Orders        10      New Customer
# 2   Average Orders        Average Orders        10      New Customer
# 3      Most Orders           Most Orders        10      New Customer
# 4   Average Orders        Average Orders        10      New Customer
# 5   Average Orders        Average Orders        10      New Customer
# 6      Most Orders           Most Orders        10      New Customer
# 7   Average Orders        Average Orders        10      New Customer
# 8   Average Orders        Average Orders        10      New Customer
# 9   Average Orders        Average Orders        22  Regular Customer
# 10  Average Orders        Average Orders        22  Regular Customer
# 11     Most Orders           Most Orders        22  Regular Customer
# 12  Average Orders        Average Orders        22  Regular Customer
# 13     Most Orders           Most Orders        22  Regular Customer
# 14     Most Orders           Most Orders         9      New Customer
# 15     Most Orders           Most Orders         9      New Customer
# 16  Average Orders        Average Orders         9      New Customer
# 17     Most Orders           Most Orders        33  Regular Customer
# 18  Average Orders        Average Orders        20  Regular Customer
# 19     Most Orders           Most Orders        20  Regular Customer
# 20  Average Orders        Average Orders        11  Regular Customer
# 21     Most Orders           Most Orders        11  Regular Customer
# 22     Most Orders           Most Orders        27  Regular Customer
# 23     Most Orders           Most Orders        27  Regular Customer
# 24     Most Orders           Most Orders        27  Regular Customer
#
#    average_prices Spending_Flag  median_order_frequency
# 0        6.372222   Low Spender                    20.5
# 1        6.372222   Low Spender                    20.5
# 2        6.372222   Low Spender                    20.5
# 3        6.372222   Low Spender                    20.5
# 4        6.372222   Low Spender                    20.5
# 5        6.372222   Low Spender                    20.5
# 6        6.372222   Low Spender                    20.5
# 7        6.372222   Low Spender                    20.5
# 8        6.372222   Low Spender                    20.5
# 9        3.994118   Low Spender                    10.0
# 10       3.994118   Low Spender                    10.0
# 11       3.994118   Low Spender                    10.0
# 12       3.994118   Low Spender                    10.0
# 13       3.994118   Low Spender                    10.0
# 14       8.464535   Low Spender                     6.0
# 15       8.464535   Low Spender                     6.0
# 16       8.464535   Low Spender                     6.0
# 17       6.987500   Low Spender                     7.5
# 18       8.203147   Low Spender                     6.0
# 19       8.203147   Low Spender                     6.0
# 20       7.323944   Low Spender                    10.0
# 21       7.323944   Low Spender                    10.0
# 22       6.330435   Low Spender                     8.0
# 23       6.330435   Low Spender                     8.0
# 24       6.330435   Low Spender                     8.0
#
# [25 rows x 24 columns]

# %%
ords_prods_merge.loc[ords_prods_merge['median_order_frequency'] > 20, 'frequency_tag'] = 'Non-frequent customer'
ords_prods_merge.loc[(ords_prods_merge['median_order_frequency'] > 10) & (ords_prods_merge['median_order_frequency'] <= 20), 'frequency_tag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['median_order_frequency'] <= 10, 'frequency_tag'] = 'Frequent customer'

# %%
ords_prods_merge['frequency_tag'].value_counts(dropna = False)
# Out:
# Frequent customer        20675290
# Regular customer          6594542
# Non-frequent customer     3058931
# Name: frequency_tag, dtype: int64

# %% [markdown]
# ## 04. Exporting Data

# %%
path2 = r'C:\Users\kensz\OneDrive\Desktop\CF Data Analytics Course\Achievement 4\11-2022 Instacart basket Analysis'

# %%
ords_prods_merge.to_pickle(os.path.join(path2, '02 Data', 'Prepared Data', 'orders_products_with_aggregates.pkl'))
